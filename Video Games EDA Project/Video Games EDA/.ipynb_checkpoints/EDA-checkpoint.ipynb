# %% [markdown]
# # <font color='maroon'><b>Loading the dataset and Dataset description</b></font>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(rc={'figure.figsize': [12,12]}, font_scale=1.1)
df = pd.read_csv('data.csv', index_col=0)
df
# Out:
#                                                    Name Platform    Year  \
# Rank
# 1                                            Wii Sports      Wii  2006.0
# 2                                     Super Mario Bros.      NES  1985.0
# 3                                        Mario Kart Wii      Wii  2008.0
# 4                                     Wii Sports Resort      Wii  2009.0
# 5                              Pokemon Red/Pokemon Blue       GB  1996.0
# ...                                                 ...      ...     ...
# 16596                Woody Woodpecker in Crazy Castle 5      GBA  2002.0
# 16597                     Men in Black II: Alien Escape       GC  2003.0
# 16598  SCORE International Baja 1000: The Official Game      PS2  2008.0
# 16599                                        Know How 2       DS  2010.0
# 16600                                  Spirits & Spells      GBA  2003.0
#
#               Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Rank
# ...

# %% [markdown]
# ## <b><font color='orange'>This is a dataset about the sales of video games, the dataset shows the sales per Region and globally all together</b></font>
# <font size=5px>The column Name describes each video game's name</font>

# %%
df['Name']
# Out:
# Rank
# 1                                              Wii Sports
# 2                                       Super Mario Bros.
# 3                                          Mario Kart Wii
# 4                                       Wii Sports Resort
# 5                                Pokemon Red/Pokemon Blue
#                                ...
# 16596                  Woody Woodpecker in Crazy Castle 5
# 16597                       Men in Black II: Alien Escape
# 16598    SCORE International Baja 1000: The Official Game
# 16599                                          Know How 2
# 16600                                    Spirits & Spells
# Name: Name, Length: 16598, dtype: object

# %% [markdown]
# #### <font size = 5px><b>Each video game is released for a specific platform or for multiple platforms all together</b></font>

# %%
df[ ['Name', 'Platform']]
# Out:
#                                                    Name Platform
# Rank
# 1                                            Wii Sports      Wii
# 2                                     Super Mario Bros.      NES
# 3                                        Mario Kart Wii      Wii
# 4                                     Wii Sports Resort      Wii
# 5                              Pokemon Red/Pokemon Blue       GB
# ...                                                 ...      ...
# 16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16597                     Men in Black II: Alien Escape       GC
# 16598  SCORE International Baja 1000: The Official Game      PS2
# 16599                                        Know How 2       DS
# 16600                                  Spirits & Spells      GBA
#
# [16598 rows x 2 columns]

# %% [markdown]
# <font size=5><b>Column "Year" represents each video game's release date.</font>
#
# <font size=3><b>Column genre represents the category/genre of the video game.</font>
# <font size=3><b>Column publisher is the studio's name.</font>
#
# <font size=3><b>The remaining columns are for each video game's sales per region and globally</b>, <b><font color=red>NOTE: The Sales numbers are in Millions.</b></font> </font>

# %%
df[  ['Year', 'Genre', 'Publisher', 'NA_Sales', 'EU_Sales', 'JP_Sales', 'Global_Sales']  ]
# Out:
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# Rank
# 1      2006.0        Sports    Nintendo     41.49     29.02      3.77
# 2      1985.0      Platform    Nintendo     29.08      3.58      6.81
# 3      2008.0        Racing    Nintendo     15.85     12.88      3.79
# 4      2009.0        Sports    Nintendo     15.75     11.01      3.28
# 5      1996.0  Role-Playing    Nintendo     11.27      8.89     10.22
# ...       ...           ...         ...       ...       ...       ...
# 16596  2002.0      Platform       Kemco      0.01      0.00      0.00
# 16597  2003.0       Shooter  Infogrames      0.01      0.00      0.00
# 16598  2008.0        Racing  Activision      0.00      0.00      0.00
# 16599  2010.0        Puzzle    7G//AMES      0.00      0.01      0.00
# 16600  2003.0      Platform     Wanadoo      0.01      0.00      0.00
#
#        Global_Sales
# Rank
# 1             82.74
# 2             40.24
# 3             35.82
# 4             33.00
# ...

# %% [markdown]
# #### <b>The column "Other Sales" is for Africa and other remaining regions</b>

# %%
df['Other_Sales']
# Out:
# Rank
# 1        8.46
# 2        0.77
# 3        3.31
# 4        2.96
# 5        1.00
#          ...
# 16596    0.00
# 16597    0.00
# 16598    0.00
# 16599    0.00
# 16600    0.00
# Name: Other_Sales, Length: 16598, dtype: float64

# %% [markdown]
# #### <b>This section will present the dataset's description and some information related to it</b>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16598 entries, 1 to 16600
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          16598 non-null  object
#  1   Platform      16598 non-null  object
#  2   Year          16327 non-null  float64
#  3   Genre         16598 non-null  object
#  4   Publisher     16540 non-null  object
#  5   NA_Sales      16598 non-null  float64
#  6   EU_Sales      16598 non-null  float64
#  7   JP_Sales      16598 non-null  float64
#  8   Other_Sales   16598 non-null  float64
#  9   Global_Sales  16598 non-null  float64
# dtypes: float64(6), object(4)
# memory usage: 1.4+ MB

# %% [markdown]
# #### As seen above the total rows are 16598, columns: Year and Publisher contains null values, which we will drop as part of data cleaning.

# %%
publisher_null =pd.isnull(df['Publisher']) # returns bool series with True/False for NaN values/Null values 
year_null= pd.isnull(df['Year'])
df[year_null] #Example to show the dataframe filtered with null values of year only.
df.dropna(inplace=True) #Drops all null values from our original data frame, inplace=True to apply changes to the original data frame
df #Data frame after removing all missing values
# Out:
#                                                    Name Platform    Year  \
# Rank
# 1                                            Wii Sports      Wii  2006.0
# 2                                     Super Mario Bros.      NES  1985.0
# 3                                        Mario Kart Wii      Wii  2008.0
# 4                                     Wii Sports Resort      Wii  2009.0
# 5                              Pokemon Red/Pokemon Blue       GB  1996.0
# ...                                                 ...      ...     ...
# 16596                Woody Woodpecker in Crazy Castle 5      GBA  2002.0
# 16597                     Men in Black II: Alien Escape       GC  2003.0
# 16598  SCORE International Baja 1000: The Official Game      PS2  2008.0
# 16599                                        Know How 2       DS  2010.0
# 16600                                  Spirits & Spells      GBA  2003.0
#
#               Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Rank
# ...

# %% [markdown]
# ## <font color='lightblue'><b>Asking the questions which will be answered to analyze the data</b></font>
# <font size=4px><b>Questions:</b></font>
#     <b><li>What is the average sales of all games?</li>
#     <li>How many type of genre are there?</li>
#     <li>When was the first game released ?</li>
#     <!-- <li>For each studio/publisher, how many games were published by each studio?</li> -->
#     <li>Since the first video game developed, which studio has the highest revenue from selling games?</li>
#     <li>Which video game genre sells the most? </li>
#     <li>What game achieved the most sales across all regions?</li>
#     <li>For each year what was the maximum number of games sold ? </li>
#     <li>For each platform how many games sold?</li>

# %% [markdown]
#  <b><li>What is the average sales of all games?</li>
# <li><font size=2px>Small note: the majority of the data </font>

# %%
test = sns.displot(data=df, x='Global_Sales');
# test.set(xlim=(0,1));
plt.xlim([0,1.5]); #adjusting the range of graph to be within 0-1

# %% [markdown]
# <font size=2  color='orange'><b>The majority(14,000+ out of 16,000 rows) of the sales are within 0-1 (number is in millions) so the scale is adjusted to give a clearer image </font>
#
# <font size=2  color='orange'><b>Remark: the majority range of sales are more concentrated in the range of 0.1-0.2 </b></font>
#
# <font size=2  color='orange'><b>Remark: explanation of the graph as follows, for example around 3000 games were sold with accumulated sales of 100,000$, whereas around only 500 games were sold for 200,000$.... etc</b>

# %% [markdown]
# <li><b>How many types of genre are there? and how many games are in each genre?</li>

# %%
df['Genre'].unique()
# Out:
# array(['Sports', 'Platform', 'Racing', 'Role-Playing', 'Puzzle', 'Misc',
#        'Shooter', 'Simulation', 'Action', 'Fighting', 'Adventure',
#        'Strategy'], dtype=object)

# %% [markdown]
# <font size=2  color='orange'><b>There are  12 Genres in total</font>

# %%
sns.countplot(data=df, x='Genre')
# Out:
# <AxesSubplot:xlabel='Genre', ylabel='count'>

# %% [markdown]
# <font size=2  color='orange'><b>Remark: The highest genres are action and Sports, having more than 2000 and more than 3000 games in these categories </font>
#
# <font size=2  color='orange'><b>Remark: The least genre category is <font size= 3 color='green'>Puzzle</font> containing just above 500 games</font>

# %% [markdown]
# <li><b>When was the first game released ?</li>

# %%
df['Year'].min()
# Out:
# 1980.0

# %%
sns.displot(data=df, x='Year',height=12);
plt.xlim(1980,2020);

# %% [markdown]
# <font size=2  color='orange'><b>Remark: Majority/Most of the games were released between 2008-2009</font>
#
# <font size=2  color='orange'><b>The first game released was in 1980</b>

# %%
sns.kdeplot(x='Year', data=df, shade=True);

# %% [markdown]
# <font size=2  color='orange'><b>This is an additional reperesntation of games released as a timeline</font>

# %%
sns.displot(data=df, x='Year', hue='Platform',multiple="stack",height=12);
plt.xlim(1980,2020);

# %% [markdown]
# <font size=2  color='orange'><b>The above graph is an additional representation of amount of games released in each year, and the amount of video games belonging to each genre </font>

# %% [markdown]
# <li><b>Since the first video game developed, which studio has the highest revenue from selling games?</li>

# %%
df[['Name','Publisher','Year','Global_Sales']]
# Out:
#                                                    Name   Publisher    Year  \
# Rank
# 1                                            Wii Sports    Nintendo  2006.0
# 2                                     Super Mario Bros.    Nintendo  1985.0
# 3                                        Mario Kart Wii    Nintendo  2008.0
# 4                                     Wii Sports Resort    Nintendo  2009.0
# 5                              Pokemon Red/Pokemon Blue    Nintendo  1996.0
# ...                                                 ...         ...     ...
# 16596                Woody Woodpecker in Crazy Castle 5       Kemco  2002.0
# 16597                     Men in Black II: Alien Escape  Infogrames  2003.0
# 16598  SCORE International Baja 1000: The Official Game  Activision  2008.0
# 16599                                        Know How 2    7G//AMES  2010.0
# 16600                                  Spirits & Spells     Wanadoo  2003.0
#
#        Global_Sales
# Rank
# 1             82.74
# ...

# %%
df['Publisher'].value_counts()
# Out:
# Electronic Arts                 1339
# Activision                       966
# Namco Bandai Games               928
# Ubisoft                          918
# Konami Digital Entertainment     823
#                                 ...
# Otomate                            1
# ITT Family Games                   1
# Universal Gamex                    1
# Intergrow                          1
# 49Games                            1
# Name: Publisher, Length: 576, dtype: int64

# %%
df.head()
# Out:
#                           Name Platform    Year         Genre Publisher  \
# Rank
# 1                   Wii Sports      Wii  2006.0        Sports  Nintendo
# 2            Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 3               Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 4            Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 5     Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#       NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Rank
# 1        41.49     29.02      3.77         8.46         82.74
# 2        29.08      3.58      6.81         0.77         40.24
# 3        15.85     12.88      3.79         3.31         35.82
# 4        15.75     11.01      3.28         2.96         33.00
# 5        11.27      8.89     10.22         1.00         31.37

# %%
#which pulisher made the most revinue ever 
maximum = df['Global_Sales'].max()
publisher = df[df['Global_Sales'] == maximum]['Publisher']
print("Publisher :",publisher, "Max : ",maximum)
# Out:
# Publisher : Rank
# 1    Nintendo
# Name: Publisher, dtype: object Max :  82.74

# %% [markdown]
# # Most pop zeft 5ararh

# %%
most_Global_Sales = df.sort_values('Global_Sales',ascending=False)[:10]

def name_and_year(row):
    return row['Name'] + " (" + str(int(row['Year'])) + ") " 

most_Global_Sales['Name and Year'] = most_Global_Sales.apply(name_and_year,axis = 1)

plt.pie(most_Global_Sales['Global_Sales'],labels = most_Global_Sales['Name and Year'],autopct='%.1f%%')
plt.show()

# %%
#all games
most_Global_Sales = df.sort_values('Global_Sales',ascending=False)#[:1000]

Genre = most_Global_Sales['Genre'].value_counts()

plt.pie(Genre,labels = Genre.index,autopct='%.1f%%')
plt.show()

# %%
#top 100
most_Global_Sales = df.sort_values('Global_Sales',ascending=False)[:100]

Genre = most_Global_Sales['Genre'].value_counts()

plt.pie(Genre,labels = Genre.index,autopct='%.1f%%')
plt.show()

# %%
most_Global_Sales['Genre'].value_counts().index
# Out:
# Index(['Platform', 'Sports', 'Shooter', 'Role-Playing', 'Misc', 'Puzzle',
#        'Racing'],
#       dtype='object')

# %%
plt.pie(most_Global_Sales['Global_Sales'],labels=most_Global_Sales['Year'])
# Out:
# ([<matplotlib.patches.Wedge at 0x19840490550>,
# ...
#  [Text(0.9950478561868642, 0.4689133863496816, '2006.0'),
#   Text(0.5039096060159232, 0.9777909331574298, '1985.0'),
#   Text(0.078065631697322, 1.0972263928413764, '2008.0'),
#   Text(-0.3200921696408525, 1.052397739894291, '2009.0'),
#   Text(-0.6550362880172543, 0.8837010022516535, '1996.0'),
#   Text(-0.9048151038970332, 0.6255474624357461, '1989.0'),
#   Text(-1.0559014596200134, 0.30833765188884327, '2006.0'),
#   Text(-1.0995026581933012, -0.03307422902903078, '2006.0'),
#   Text(-1.0381770049796655, -0.3635773732391111, '2009.0'),
#   Text(-0.8823918175323346, -0.6567988126907534, '1984.0'),
#   Text(-0.6643592793341071, -0.8767136065800885, '2005.0'),
#   Text(-0.4202687665000976, -1.01655012857433, '2005.0'),
#   Text(-0.158316237924772, -1.0885476419566336, '1999.0'),
#   Text(0.10921533000708565, -1.0945647590213399, '2007.0'),
#   Text(0.36421273329117276, -1.037954278814136, '2009.0'),
# ...

# %%
df[['Genre','Platform','Global_Sales']]
# Out:
#               Global_Sales
# Global_Sales           1.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16598 entries, 1 to 16600
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          16598 non-null  object
#  1   Platform      16598 non-null  object
#  2   Year          16327 non-null  float64
#  3   Genre         16598 non-null  object
#  4   Publisher     16540 non-null  object
#  5   NA_Sales      16598 non-null  float64
#  6   EU_Sales      16598 non-null  float64
#  7   JP_Sales      16598 non-null  float64
#  8   Other_Sales   16598 non-null  float64
#  9   Global_Sales  16598 non-null  float64
# dtypes: float64(6), object(4)
# memory usage: 1.4+ MB

# %%
df.describe().min()['Global_Sales']
# Out:
# 0.01
