# %%
#make a program that get all users data including name, username, email, street, suite, city, zip code, geo_lat, geo_long, phone,
# website, company name and then save them in a CSV & Excel file.
import pandas as pd
import requests, csv
response = requests.get('https://jsonplaceholder.typicode.com/users')
userData = response.json()

# %%
with open ('user_information.csv', 'w', newline='') as userInfo:
    writer = csv.DictWriter(userInfo, ['Name', 'Username', 'Email', 'Street','Suite','City','Zip Code', 'Geographical Latitude', 'Geographical longitude', 'Phone', 'Website', 'Company Name'])
    writer.writeheader()
    for data in userData:
        name = data['name']
        username = data['username']
        email= data['email']
        street= data['address']['street']
        suite = data['address']['suite']
        city = data['address']['city']
        zipcode= data['address']['zipcode']
        geo_lat = data['address']['geo']['lat']
        geo_long= data['address']['geo']['lng']
        phone = data['phone']
        website = data['website']
        company_name = data['company']['name']
        writer.writerow({'Name':name, 'Username':username, 'Email':email, 'Street':street, 'Suite':suite, 'City':city, 'Zip Code':zipcode,
         'Geographical Latitude':geo_lat, 'Geographical longitude':geo_long, 'Phone':phone, 'Website':website, 'Company Name':company_name})

# %%
df = pd.read_csv('user_information.csv')
# Out:
#                        Name          Username                      Email  \
# 0             Leanne Graham              Bret          Sincere@april.biz
# 1              Ervin Howell         Antonette          Shanna@melissa.tv
# 2          Clementine Bauch          Samantha         Nathan@yesenia.net
# 3          Patricia Lebsack          Karianne  Julianne.OConner@kory.org
# 4          Chelsey Dietrich            Kamren   Lucio_Hettinger@annie.ca
# 5      Mrs. Dennis Schulist  Leopoldo_Corkery    Karley_Dach@jasper.info
# 6           Kurtis Weissnat      Elwyn.Skiles     Telly.Hoeger@billy.biz
# 7  Nicholas Runolfsdottir V     Maxime_Nienow       Sherwood@rosamond.me
# 8           Glenna Reichert          Delphine    Chaim_McDermott@dana.io
# 9        Clementina DuBuque    Moriah.Stanton     Rey.Padberg@karina.biz
#
#               Street      Suite            City    Zip Code  \
# 0        Kulas Light   Apt. 556     Gwenborough  92998-3874
# ...

# %%
df_excel = df.to_excel('user_information.xlsx', index=False)
df_excel = pd.read_excel('user_information.xlsx')
df_excel
# Out:
#                        Name          Username                      Email  \
# 0             Leanne Graham              Bret          Sincere@april.biz
# 1              Ervin Howell         Antonette          Shanna@melissa.tv
# 2          Clementine Bauch          Samantha         Nathan@yesenia.net
# 3          Patricia Lebsack          Karianne  Julianne.OConner@kory.org
# 4          Chelsey Dietrich            Kamren   Lucio_Hettinger@annie.ca
# 5      Mrs. Dennis Schulist  Leopoldo_Corkery    Karley_Dach@jasper.info
# 6           Kurtis Weissnat      Elwyn.Skiles     Telly.Hoeger@billy.biz
# 7  Nicholas Runolfsdottir V     Maxime_Nienow       Sherwood@rosamond.me
# 8           Glenna Reichert          Delphine    Chaim_McDermott@dana.io
# 9        Clementina DuBuque    Moriah.Stanton     Rey.Padberg@karina.biz
#
#               Street      Suite            City    Zip Code  \
# 0        Kulas Light   Apt. 556     Gwenborough  92998-3874
# ...
